# %% [markdown]
# # Spatial transcriptomics unveils the in situ cellular and molecular hallmarks of the lung in fatal COVID-19

# %% [markdown]
# # Process Human Lung Cell Atlas (HLCA) core object to use it as reference dataset for deconvolution and mapping of Visium ST data.

# %% [markdown]
# **Author:** Carlos A. Garcia-Prieto
#
# * This notebook explains the processing of the HLCA core annData object to use it as a reference single-cell dataset for deconvolution and mapping of the studied Visium ST samples.
# * See the [HLCA paper](https://doi.org/10.1038/s41591-023-02327-2) for more details and to download [HLCA core annData object.](https://cellxgene.cziscience.com/collections/6f6d381a-7701-4781-935c-db10d30de293)

# %% [markdown]
# ## Import modules

# %%
import anndata
import matplotlib.pyplot as plt
import scanpy as sc
import pandas as pd
import seaborn as sns
import scanpy.external as sce
import numpy as np

# %%
pd.set_option('display.max_rows', 250)
pd.set_option('display.max_columns', 500)

# %%
#Read HLCA core annData object
HLCA_core = anndata.read(f'/Users/carlosgarciaprieto/Proyectos_IJC/Spatial/COVID/Results/Python/HLCA_publication/HLCA_core.h5ad')

# %%
#Explore HLCA core
HLCA_core
# Out:
# AnnData object with n_obs × n_vars = 584944 × 28024
#     obs: 'suspension_type', 'donor_id', 'is_primary_data', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'tissue_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'BMI', 'age_or_mean_of_age_range', 'age_range', 'anatomical_region_ccf_score', 'ann_coarse_for_GWAS_and_modeling', 'ann_finest_level', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'cause_of_death', 'dataset', 'entropy_dataset_leiden_3', 'entropy_original_ann_level_1_leiden_3', 'entropy_original_ann_level_2_clean_leiden_3', 'entropy_original_ann_level_3_clean_leiden_3', 'entropy_subject_ID_leiden_3', 'fresh_or_frozen', 'leiden_1', 'leiden_2', 'leiden_3', 'leiden_4', 'leiden_5', 'log10_total_counts', 'lung_condition', 'mixed_ancestry', 'n_genes_detected', 'original_ann_highest_res', 'original_ann_level_1', 'original_ann_level_2', 'original_ann_level_3', 'original_ann_level_4', 'original_ann_level_5', 'original_ann_nonharmonized', 'reannotation_type', 'reference_genome', 'sample', 'scanvi_label', 'sequencing_platform', 'size_factors', 'smoking_status', 'study', 'subject_type', 'tissue_dissociation_protocol', 'tissue_level_2', 'tissue_level_3', 'tissue_sampling_method', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'batch_condition', 'default_embedding', 'schema_version', 'title'
#     obsm: 'X_scanvi_emb', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
HLCA_core.obs
# Out:
#                         suspension_type  \
# GCGACCATCCCTAACC_SC22              cell
# P2_1_GCGCAACCAGTTAACC              cell
# GCTCTGTAGTGCTGCC_SC27              cell
# P2_8_TTAGGACGTTCAGGCC              cell
# CTTGATTGTCAGTTTG_T164              cell
# ...                                 ...
# ACCTTTACATTAACCG_T120              cell
# CATTATCTCCATGAAC_F01639            cell
# AGGCCGTGTGTGACCC-SC56              cell
# CGATGGCAGCAGGCTA-1-2               cell
# AATCGGTGTCGGCACT-1-4               cell
#
#                                                                   donor_id  \
# GCGACCATCCCTAACC_SC22    homosapiens_None_2023_None_sikkemalisa_001_d10...
# P2_1_GCGCAACCAGTTAACC    homosapiens_None_2023_None_sikkemalisa_001_d10...
# GCTCTGTAGTGCTGCC_SC27    homosapiens_None_2023_None_sikkemalisa_001_d10...
# P2_8_TTAGGACGTTCAGGCC    homosapiens_None_2023_None_sikkemalisa_001_d10...
# CTTGATTGTCAGTTTG_T164    homosapiens_None_2023_None_sikkemalisa_001_d10...
# ...                                                                    ...
# ACCTTTACATTAACCG_T120    homosapiens_None_2023_None_sikkemalisa_001_d10...
# CATTATCTCCATGAAC_F01639  homosapiens_None_2023_None_sikkemalisa_001_d10...
# AGGCCGTGTGTGACCC-SC56    homosapiens_None_2023_None_sikkemalisa_001_d10...
# CGATGGCAGCAGGCTA-1-2     homosapiens_None_2023_None_sikkemalisa_001_d10...
# AATCGGTGTCGGCACT-1-4     homosapiens_None_2023_None_sikkemalisa_001_d10...
#
#                          is_primary_data assay_ontology_term_id  \
# GCGACCATCCCTAACC_SC22              False            EFO:0009899
# P2_1_GCGCAACCAGTTAACC              False            EFO:0009899
# GCTCTGTAGTGCTGCC_SC27              False            EFO:0009899
# P2_8_TTAGGACGTTCAGGCC              False            EFO:0009899
# CTTGATTGTCAGTTTG_T164              False            EFO:0009922
# ...                                  ...                    ...
# ACCTTTACATTAACCG_T120              False            EFO:0009899
# CATTATCTCCATGAAC_F01639            False            EFO:0011025
# AGGCCGTGTGTGACCC-SC56              False            EFO:0009899
# CGATGGCAGCAGGCTA-1-2               False            EFO:0011025
# AATCGGTGTCGGCACT-1-4               False            EFO:0009900
#
#                         cell_type_ontology_term_id  \
# GCGACCATCCCTAACC_SC22                   CL:0000583
# P2_1_GCGCAACCAGTTAACC                   CL:0000623
# GCTCTGTAGTGCTGCC_SC27                   CL:0002063
# P2_8_TTAGGACGTTCAGGCC                   CL:0000583
# CTTGATTGTCAGTTTG_T164                   CL:0002633
# ...                                            ...
# ACCTTTACATTAACCG_T120                   CL:0002633
# CATTATCTCCATGAAC_F01639                 CL:0002399
# AGGCCGTGTGTGACCC-SC56                   CL:0002063
# CGATGGCAGCAGGCTA-1-2                    CL:0000158
# AATCGGTGTCGGCACT-1-4                    CL:0000158
#
#                         development_stage_ontology_term_id  \
# GCGACCATCCCTAACC_SC22                       HsapDv:0000143
# P2_1_GCGCAACCAGTTAACC                       HsapDv:0000140
# GCTCTGTAGTGCTGCC_SC27                       HsapDv:0000141
# P2_8_TTAGGACGTTCAGGCC                       HsapDv:0000140
# CTTGATTGTCAGTTTG_T164                       HsapDv:0000160
# ...                                                    ...
# ACCTTTACATTAACCG_T120                       HsapDv:0000151
# CATTATCTCCATGAAC_F01639                     HsapDv:0000147
# AGGCCGTGTGTGACCC-SC56                       HsapDv:0000151
# CGATGGCAGCAGGCTA-1-2                        HsapDv:0000135
# AATCGGTGTCGGCACT-1-4                        HsapDv:0000121
#
#                         disease_ontology_term_id  \
# GCGACCATCCCTAACC_SC22               PATO:0000461
# P2_1_GCGCAACCAGTTAACC               PATO:0000461
# GCTCTGTAGTGCTGCC_SC27               PATO:0000461
# P2_8_TTAGGACGTTCAGGCC               PATO:0000461
# CTTGATTGTCAGTTTG_T164               PATO:0000461
# ...                                          ...
# ACCTTTACATTAACCG_T120               PATO:0000461
# CATTATCTCCATGAAC_F01639             PATO:0000461
# AGGCCGTGTGTGACCC-SC56               PATO:0000461
# CGATGGCAGCAGGCTA-1-2                PATO:0000461
# AATCGGTGTCGGCACT-1-4                PATO:0000461
#
#                         self_reported_ethnicity_ontology_term_id  \
# GCGACCATCCCTAACC_SC22                             HANCESTRO:0005
# P2_1_GCGCAACCAGTTAACC                             HANCESTRO:0005
# GCTCTGTAGTGCTGCC_SC27                             HANCESTRO:0005
# P2_8_TTAGGACGTTCAGGCC                             HANCESTRO:0005
# CTTGATTGTCAGTTTG_T164                             HANCESTRO:0005
# ...                                                          ...
# ACCTTTACATTAACCG_T120                             HANCESTRO:0005
# CATTATCTCCATGAAC_F01639                           HANCESTRO:0005
# AGGCCGTGTGTGACCC-SC56                             HANCESTRO:0005
# CGATGGCAGCAGGCTA-1-2                              HANCESTRO:0005
# AATCGGTGTCGGCACT-1-4                              HANCESTRO:0306
#
#                         tissue_ontology_term_id organism_ontology_term_id  \
# GCGACCATCCCTAACC_SC22            UBERON:0008946            NCBITaxon:9606
# P2_1_GCGCAACCAGTTAACC            UBERON:0008946            NCBITaxon:9606
# GCTCTGTAGTGCTGCC_SC27            UBERON:0008946            NCBITaxon:9606
# P2_8_TTAGGACGTTCAGGCC            UBERON:0001005            NCBITaxon:9606
# CTTGATTGTCAGTTTG_T164            UBERON:0001005            NCBITaxon:9606
# ...                                         ...                       ...
# ACCTTTACATTAACCG_T120            UBERON:0001005            NCBITaxon:9606
# CATTATCTCCATGAAC_F01639          UBERON:0008946            NCBITaxon:9606
# AGGCCGTGTGTGACCC-SC56            UBERON:0008946            NCBITaxon:9606
# CGATGGCAGCAGGCTA-1-2             UBERON:0000004            NCBITaxon:9606
# AATCGGTGTCGGCACT-1-4             UBERON:0000004            NCBITaxon:9606
#
#                         sex_ontology_term_id     BMI  \
# GCGACCATCCCTAACC_SC22           PATO:0000383     NaN
# P2_1_GCGCAACCAGTTAACC           PATO:0000384  33.100
# GCTCTGTAGTGCTGCC_SC27           PATO:0000383     NaN
# P2_8_TTAGGACGTTCAGGCC           PATO:0000384  33.100
# CTTGATTGTCAGTTTG_T164           PATO:0000384  28.903
# ...                                      ...     ...
# ACCTTTACATTAACCG_T120           PATO:0000383  22.039
# CATTATCTCCATGAAC_F01639         PATO:0000384  33.800
# AGGCCGTGTGTGACCC-SC56           PATO:0000383     NaN
# CGATGGCAGCAGGCTA-1-2            PATO:0000384  19.900
# AATCGGTGTCGGCACT-1-4            PATO:0000383  28.200
#
#                          age_or_mean_of_age_range age_range  \
# GCGACCATCCCTAACC_SC22                        49.0       NaN
# P2_1_GCGCAACCAGTTAACC                        46.0       NaN
# GCTCTGTAGTGCTGCC_SC27                        47.0       NaN
# P2_8_TTAGGACGTTCAGGCC                        46.0       NaN
# CTTGATTGTCAGTTTG_T164                        66.0       NaN
# ...                                           ...       ...
# ACCTTTACATTAACCG_T120                        57.0       NaN
# CATTATCTCCATGAAC_F01639                      53.0       NaN
# AGGCCGTGTGTGACCC-SC56                        57.0       NaN
# CGATGGCAGCAGGCTA-1-2                         41.0       NaN
# AATCGGTGTCGGCACT-1-4                         27.0       NaN
#
#                          anatomical_region_ccf_score  \
# GCGACCATCCCTAACC_SC22                           0.97
# P2_1_GCGCAACCAGTTAACC                           0.97
# GCTCTGTAGTGCTGCC_SC27                           0.97
# P2_8_TTAGGACGTTCAGGCC                           0.81
# CTTGATTGTCAGTTTG_T164                           0.36
# ...                                              ...
# ACCTTTACATTAACCG_T120                           0.36
# CATTATCTCCATGAAC_F01639                         0.97
# AGGCCGTGTGTGACCC-SC56                           0.97
# CGATGGCAGCAGGCTA-1-2                            0.00
# AATCGGTGTCGGCACT-1-4                            0.00
#
#                         ann_coarse_for_GWAS_and_modeling  \
# GCGACCATCCCTAACC_SC22               Alveolar macrophages
# P2_1_GCGCAACCAGTTAACC            Innate lymphoid cell NK
# GCTCTGTAGTGCTGCC_SC27                                AT2
# P2_8_TTAGGACGTTCAGGCC               Alveolar macrophages
# CTTGATTGTCAGTTTG_T164                              Basal
# ...                                                  ...
# ACCTTTACATTAACCG_T120                              Basal
# CATTATCTCCATGAAC_F01639                              DC2
# AGGCCGTGTGTGACCC-SC56                                AT2
# CGATGGCAGCAGGCTA-1-2                           Secretory
# AATCGGTGTCGGCACT-1-4                           Secretory
#
#                              ann_finest_level ann_level_1  \
# GCGACCATCCCTAACC_SC22    Alveolar macrophages      Immune
# P2_1_GCGCAACCAGTTAACC                NK cells      Immune
# GCTCTGTAGTGCTGCC_SC27                     AT2  Epithelial
# P2_8_TTAGGACGTTCAGGCC      Alveolar Mph CCL3+      Immune
# CTTGATTGTCAGTTTG_T164              Suprabasal  Epithelial
# ...                                       ...         ...
# ACCTTTACATTAACCG_T120              Suprabasal  Epithelial
# CATTATCTCCATGAAC_F01639                   DC2      Immune
# AGGCCGTGTGTGACCC-SC56                     AT2  Epithelial
# CGATGGCAGCAGGCTA-1-2             Club (nasal)  Epithelial
# AATCGGTGTCGGCACT-1-4             Club (nasal)  Epithelial
#
#                                  ann_level_2              ann_level_3  \
# GCGACCATCCCTAACC_SC22                Myeloid              Macrophages
# P2_1_GCGCAACCAGTTAACC               Lymphoid  Innate lymphoid cell NK
# GCTCTGTAGTGCTGCC_SC27    Alveolar epithelium                      AT2
# P2_8_TTAGGACGTTCAGGCC                Myeloid              Macrophages
# CTTGATTGTCAGTTTG_T164      Airway epithelium                    Basal
# ...                                      ...                      ...
# ACCTTTACATTAACCG_T120      Airway epithelium                    Basal
# CATTATCTCCATGAAC_F01639              Myeloid          Dendritic cells
# AGGCCGTGTGTGACCC-SC56    Alveolar epithelium                      AT2
# CGATGGCAGCAGGCTA-1-2       Airway epithelium                Secretory
# AATCGGTGTCGGCACT-1-4       Airway epithelium                Secretory
#
#                                   ann_level_4         ann_level_5  \
# GCGACCATCCCTAACC_SC22    Alveolar macrophages                None
# P2_1_GCGCAACCAGTTAACC                NK cells                None
# GCTCTGTAGTGCTGCC_SC27                    None                None
# P2_8_TTAGGACGTTCAGGCC    Alveolar macrophages  Alveolar Mph CCL3+
# CTTGATTGTCAGTTTG_T164              Suprabasal                None
# ...                                       ...                 ...
# ACCTTTACATTAACCG_T120              Suprabasal                None
# CATTATCTCCATGAAC_F01639                   DC2                None
# AGGCCGTGTGTGACCC-SC56                    None                None
# CGATGGCAGCAGGCTA-1-2                     Club        Club (nasal)
# AATCGGTGTCGGCACT-1-4                     Club        Club (nasal)
#
#                                   cause_of_death                    dataset  \
# GCGACCATCCCTAACC_SC22    intracranial hemorrhage     Misharin_Budinger_2018
# P2_1_GCGCAACCAGTTAACC                        NaN               Krasnow_2020
# GCTCTGTAGTGCTGCC_SC27    intracranial hemorrhage     Misharin_Budinger_2018
# P2_8_TTAGGACGTTCAGGCC                        NaN               Krasnow_2020
# CTTGATTGTCAGTTTG_T164                        NaN         Seibold_2020_10Xv3
# ...                                          ...                        ...
# ACCTTTACATTAACCG_T120                        NaN         Seibold_2020_10Xv2
# CATTATCTCCATGAAC_F01639                      NaN      Banovich_Kropski_2020
# AGGCCGTGTGTGACCC-SC56                        NaN  Lafyatis_Rojas_2019_10Xv2
# CGATGGCAGCAGGCTA-1-2                         NaN   Jain_Misharin_2021_10Xv1
# AATCGGTGTCGGCACT-1-4                         NaN   Jain_Misharin_2021_10Xv2
#
#                          entropy_dataset_leiden_3  \
# GCGACCATCCCTAACC_SC22                    1.664049
# P2_1_GCGCAACCAGTTAACC                    1.461924
# GCTCTGTAGTGCTGCC_SC27                    1.381972
# P2_8_TTAGGACGTTCAGGCC                    1.005008
# CTTGATTGTCAGTTTG_T164                    1.377439
# ...                                           ...
# ACCTTTACATTAACCG_T120                    1.631233
# CATTATCTCCATGAAC_F01639                  2.148653
# AGGCCGTGTGTGACCC-SC56                    1.381972
# CGATGGCAGCAGGCTA-1-2                     1.404169
# AATCGGTGTCGGCACT-1-4                     1.404169
#
#                          entropy_original_ann_level_1_leiden_3  \
# GCGACCATCCCTAACC_SC22                                 0.177918
# P2_1_GCGCAACCAGTTAACC                                 0.013459
# GCTCTGTAGTGCTGCC_SC27                                 0.280016
# P2_8_TTAGGACGTTCAGGCC                                 0.002307
# CTTGATTGTCAGTTTG_T164                                 0.006080
# ...                                                        ...
# ACCTTTACATTAACCG_T120                                 0.016913
# CATTATCTCCATGAAC_F01639                               0.099850
# AGGCCGTGTGTGACCC-SC56                                 0.280016
# CGATGGCAGCAGGCTA-1-2                                  0.004833
# AATCGGTGTCGGCACT-1-4                                  0.004833
#
#                          entropy_original_ann_level_2_clean_leiden_3  \
# GCGACCATCCCTAACC_SC22                                       0.182714
# P2_1_GCGCAACCAGTTAACC                                       0.015608
# GCTCTGTAGTGCTGCC_SC27                                       0.208872
# P2_8_TTAGGACGTTCAGGCC                                       0.019563
# CTTGATTGTCAGTTTG_T164                                       0.018198
# ...                                                              ...
# ACCTTTACATTAACCG_T120                                       0.273477
# CATTATCTCCATGAAC_F01639                                     0.091353
# AGGCCGTGTGTGACCC-SC56                                       0.208872
# CGATGGCAGCAGGCTA-1-2                                        0.014457
# AATCGGTGTCGGCACT-1-4                                        0.014457
#
#                          entropy_original_ann_level_3_clean_leiden_3  \
# GCGACCATCCCTAACC_SC22                                       0.277385
# P2_1_GCGCAACCAGTTAACC                                       0.326962
# GCTCTGTAGTGCTGCC_SC27                                       0.388602
# P2_8_TTAGGACGTTCAGGCC                                       0.062629
# CTTGATTGTCAGTTTG_T164                                       0.159813
# ...                                                              ...
# ACCTTTACATTAACCG_T120                                       0.387291
# CATTATCTCCATGAAC_F01639                                     1.151454
# AGGCCGTGTGTGACCC-SC56                                       0.388602
# CGATGGCAGCAGGCTA-1-2                                        0.700806
# AATCGGTGTCGGCACT-1-4                                        0.700806
#
#                          entropy_subject_ID_leiden_3 fresh_or_frozen leiden_1  \
# GCGACCATCCCTAACC_SC22                       2.602398           fresh        1
# P2_1_GCGCAACCAGTTAACC                       2.729274           fresh        1
# GCTCTGTAGTGCTGCC_SC27                       2.006138           fresh        0
# P2_8_TTAGGACGTTCAGGCC                       1.192024           fresh        1
# CTTGATTGTCAGTTTG_T164                       3.217918          frozen        0
# ...                                              ...             ...      ...
# ACCTTTACATTAACCG_T120                       2.790810          frozen        0
# CATTATCTCCATGAAC_F01639                     3.716129           fresh        1
# AGGCCGTGTGTGACCC-SC56                       2.006138           fresh        0
# CGATGGCAGCAGGCTA-1-2                        2.782702           fresh        0
# AATCGGTGTCGGCACT-1-4                        2.782702           fresh        0
#
#                         leiden_2 leiden_3 leiden_4 leiden_5  \
# GCGACCATCCCTAACC_SC22        1.0    1.0.0  1.0.0.0      NaN
# P2_1_GCGCAACCAGTTAACC        1.3    1.3.0  1.3.0.0      NaN
# GCTCTGTAGTGCTGCC_SC27        0.1    0.1.2  0.1.2.0      NaN
# P2_8_TTAGGACGTTCAGGCC        1.0    1.0.2  1.0.2.0      NaN
# CTTGATTGTCAGTTTG_T164        0.0    0.0.1  0.0.1.1      NaN
# ...                          ...      ...      ...      ...
# ACCTTTACATTAACCG_T120        0.0    0.0.2  0.0.2.3      NaN
# CATTATCTCCATGAAC_F01639      1.2    1.2.1  1.2.1.0      NaN
# AGGCCGTGTGTGACCC-SC56        0.1    0.1.2  0.1.2.0      NaN
# CGATGGCAGCAGGCTA-1-2         0.2    0.2.1  0.2.1.0      NaN
# AATCGGTGTCGGCACT-1-4         0.2    0.2.1  0.2.1.0      NaN
#
#                          log10_total_counts            lung_condition  \
# GCGACCATCCCTAACC_SC22              4.016197                   Healthy
# P2_1_GCGCAACCAGTTAACC              3.203848  Healthy (tumor adjacent)
# GCTCTGTAGTGCTGCC_SC27              3.493458                   Healthy
# P2_8_TTAGGACGTTCAGGCC              4.242591  Healthy (tumor adjacent)
# CTTGATTGTCAGTTTG_T164              4.733551                   Healthy
# ...                                     ...                       ...
# ACCTTTACATTAACCG_T120              4.184152                   Healthy
# CATTATCTCCATGAAC_F01639            4.007705                   Healthy
# AGGCCGTGTGTGACCC-SC56              4.076422                   Healthy
# CGATGGCAGCAGGCTA-1-2               3.653309                   Healthy
# AATCGGTGTCGGCACT-1-4               3.176959                   Healthy
#
#                          mixed_ancestry  n_genes_detected  \
# GCGACCATCCCTAACC_SC22               NaN              2438
# P2_1_GCGCAACCAGTTAACC               NaN               700
# GCTCTGTAGTGCTGCC_SC27               NaN              1200
# P2_8_TTAGGACGTTCAGGCC               NaN              3286
# CTTGATTGTCAGTTTG_T164               NaN              6891
# ...                                 ...               ...
# ACCTTTACATTAACCG_T120               NaN              3177
# CATTATCTCCATGAAC_F01639             NaN              2590
# AGGCCGTGTGTGACCC-SC56               NaN              2848
# CGATGGCAGCAGGCTA-1-2                NaN              1899
# AATCGGTGTCGGCACT-1-4     european/asian               830
#
#                          original_ann_highest_res original_ann_level_1  \
# GCGACCATCCCTAACC_SC22                           4               Immune
# P2_1_GCGCAACCAGTTAACC                           4               Immune
# GCTCTGTAGTGCTGCC_SC27                           3           Epithelial
# P2_8_TTAGGACGTTCAGGCC                           4               Immune
# CTTGATTGTCAGTTTG_T164                           4           Epithelial
# ...                                           ...                  ...
# ACCTTTACATTAACCG_T120                           4           Epithelial
# CATTATCTCCATGAAC_F01639                         4               Immune
# AGGCCGTGTGTGACCC-SC56                           3           Epithelial
# CGATGGCAGCAGGCTA-1-2                            4           Epithelial
# AATCGGTGTCGGCACT-1-4                            4           Epithelial
#
#                         original_ann_level_2     original_ann_level_3  \
# GCGACCATCCCTAACC_SC22                Myeloid              Macrophages
# P2_1_GCGCAACCAGTTAACC               Lymphoid  Innate lymphoid cell NK
# GCTCTGTAGTGCTGCC_SC27    Alveolar epithelium                      AT2
# P2_8_TTAGGACGTTCAGGCC                Myeloid              Macrophages
# CTTGATTGTCAGTTTG_T164      Airway epithelium                    Basal
# ...                                      ...                      ...
# ACCTTTACATTAACCG_T120      Airway epithelium                    Basal
# CATTATCTCCATGAAC_F01639              Myeloid          Dendritic cells
# AGGCCGTGTGTGACCC-SC56    Alveolar epithelium                      AT2
# CGATGGCAGCAGGCTA-1-2       Airway epithelium                Secretory
# AATCGGTGTCGGCACT-1-4       Airway epithelium                Secretory
#
#                          original_ann_level_4 original_ann_level_5  \
# GCGACCATCCCTAACC_SC22    Alveolar macrophages                 None
# P2_1_GCGCAACCAGTTAACC                NK cells                 None
# GCTCTGTAGTGCTGCC_SC27                    None                 None
# P2_8_TTAGGACGTTCAGGCC    Alveolar macrophages                 None
# CTTGATTGTCAGTTTG_T164         KRT8 high basal                 None
# ...                                       ...                  ...
# ACCTTTACATTAACCG_T120         KRT8 high basal                 None
# CATTATCTCCATGAAC_F01639                   DC1                 None
# AGGCCGTGTGTGACCC-SC56                    None                 None
# CGATGGCAGCAGGCTA-1-2                     Club                 None
# AATCGGTGTCGGCACT-1-4                     Club                 None
#
#                                original_ann_nonharmonized  \
# GCGACCATCCCTAACC_SC22                Alveolar macrophages
# P2_1_GCGCAACCAGTTAACC                      Natural Killer
# GCTCTGTAGTGCTGCC_SC27    Alveolar epithelial type 2 cells
# P2_8_TTAGGACGTTCAGGCC                          Macrophage
# CTTGATTGTCAGTTTG_T164                           KRT8.high
# ...                                                   ...
# ACCTTTACATTAACCG_T120                           KRT8.high
# CATTATCTCCATGAAC_F01639                              cDC1
# AGGCCGTGTGTGACCC-SC56                               6 AT2
# CGATGGCAGCAGGCTA-1-2                                 Club
# AATCGGTGTCGGCACT-1-4                                 Club
#
#                            reannotation_type        reference_genome  \
# GCGACCATCCCTAACC_SC22    Correctly annotated  Homo_sapiens.GRCh38.84
# P2_1_GCGCAACCAGTTAACC    Correctly annotated  Homo_sapiens.GRCh38.84
# GCTCTGTAGTGCTGCC_SC27    Correctly annotated  Homo_sapiens.GRCh38.84
# P2_8_TTAGGACGTTCAGGCC         Underannotated  Homo_sapiens.GRCh38.84
# CTTGATTGTCAGTTTG_T164           Misannotated  Homo_sapiens.GRCh38.84
# ...                                      ...                     ...
# ACCTTTACATTAACCG_T120           Misannotated  Homo_sapiens.GRCh38.84
# CATTATCTCCATGAAC_F01639         Misannotated  Homo_sapiens.GRCh38.84
# AGGCCGTGTGTGACCC-SC56    Correctly annotated  Homo_sapiens.GRCh38.93
# CGATGGCAGCAGGCTA-1-2          Underannotated  Homo_sapiens.GRCh38.84
# AATCGGTGTCGGCACT-1-4          Underannotated  Homo_sapiens.GRCh38.84
#
#                               sample     scanvi_label  \
# GCGACCATCCCTAACC_SC22           SC22      Macrophages
# P2_1_GCGCAACCAGTTAACC       distal 2    Non-T/B cells
# GCTCTGTAGTGCTGCC_SC27           SC27              AT2
# P2_8_TTAGGACGTTCAGGCC       medial 2      Macrophages
# CTTGATTGTCAGTTTG_T164           T164            Basal
# ...                              ...              ...
# ACCTTTACATTAACCG_T120           T120            Basal
# CATTATCTCCATGAAC_F01639       F01639  Dendritic cells
# AGGCCGTGTGTGACCC-SC56           SC56              AT2
# CGATGGCAGCAGGCTA-1-2     SC174_SC173        Secretory
# AATCGGTGTCGGCACT-1-4           SC182        Secretory
#
#                               sequencing_platform  size_factors  \
# GCGACCATCCCTAACC_SC22         Illumina HiSeq 4000      0.998238
# P2_1_GCGCAACCAGTTAACC       Illumina NovaSeq 6000      0.172927
# GCTCTGTAGTGCTGCC_SC27         Illumina HiSeq 4000      0.343101
# P2_8_TTAGGACGTTCAGGCC       Illumina NovaSeq 6000      1.571874
# CTTGATTGTCAGTTTG_T164       Illumina NovaSeq 6000      7.520303
# ...                                           ...           ...
# ACCTTTACATTAACCG_T120       Illumina NovaSeq 6000      1.801739
# CATTATCTCCATGAAC_F01639  Illumina NovaSeq 6000 S2      1.169098
# AGGCCGTGTGTGACCC-SC56        Illumina NextSeq 500      1.401193
# CGATGGCAGCAGGCTA-1-2        Illumina NovaSeq 6000      0.746264
# AATCGGTGTCGGCACT-1-4        Illumina NovaSeq 6000      0.281445
#
#                         smoking_status                   study   subject_type  \
# GCGACCATCCCTAACC_SC22           active  Misharin_Budinger_2018    organ_donor
# P2_1_GCGCAACCAGTTAACC            never            Krasnow_2020  alive_disease
# GCTCTGTAGTGCTGCC_SC27           active  Misharin_Budinger_2018    organ_donor
# P2_8_TTAGGACGTTCAGGCC            never            Krasnow_2020  alive_disease
# CTTGATTGTCAGTTTG_T164            never            Seibold_2020    organ_donor
# ...                                ...                     ...            ...
# ACCTTTACATTAACCG_T120           active            Seibold_2020    organ_donor
# CATTATCTCCATGAAC_F01639         active   Banovich_Kropski_2020    organ_donor
# AGGCCGTGTGTGACCC-SC56            never     Lafyatis_Rojas_2019    organ_donor
# CGATGGCAGCAGGCTA-1-2             never      Jain_Misharin_2021  alive_healthy
# AATCGGTGTCGGCACT-1-4               NaN      Jain_Misharin_2021  alive_healthy
#
#                            tissue_dissociation_protocol  \
# GCGACCATCCCTAACC_SC22             Collagenase D + DNAse
# P2_1_GCGCAACCAGTTAACC    Collagenase + Elastase + DNAse
# GCTCTGTAGTGCTGCC_SC27             Collagenase D + DNAse
# P2_8_TTAGGACGTTCAGGCC    Collagenase + Elastase + DNAse
# CTTGATTGTCAGTTTG_T164           Cold protease overnight
# ...                                                 ...
# ACCTTTACATTAACCG_T120           Cold protease overnight
# CATTATCTCCATGAAC_F01639           Dispase + collagenase
# AGGCCGTGTGTGACCC-SC56             Collagenase A + DNAse
# CGATGGCAGCAGGCTA-1-2                   Cold protease 1h
# AATCGGTGTCGGCACT-1-4                   Cold protease 1h
#
#                                        tissue_level_2  \
# GCGACCATCCCTAACC_SC22           parenchyma lower lobe
# P2_1_GCGCAACCAGTTAACC    parenchyma right middle lobe
# GCTCTGTAGTGCTGCC_SC27           parenchyma lower lobe
# P2_8_TTAGGACGTTCAGGCC          distal lobular airways
# CTTGATTGTCAGTTTG_T164                         trachea
# ...                                               ...
# ACCTTTACATTAACCG_T120                         trachea
# CATTATCTCCATGAAC_F01639                           NaN
# AGGCCGTGTGTGACCC-SC56                             NaN
# CGATGGCAGCAGGCTA-1-2               inferior turbinate
# AATCGGTGTCGGCACT-1-4               inferior turbinate
#
#                                            tissue_level_3  \
# GCGACCATCCCTAACC_SC22                                 NaN
# P2_1_GCGCAACCAGTTAACC                                 NaN
# GCTCTGTAGTGCTGCC_SC27                                 NaN
# P2_8_TTAGGACGTTCAGGCC    distal airways middle right lobe
# CTTGATTGTCAGTTTG_T164                                 NaN
# ...                                                   ...
# ACCTTTACATTAACCG_T120                                 NaN
# CATTATCTCCATGAAC_F01639                               NaN
# AGGCCGTGTGTGACCC-SC56                                 NaN
# CGATGGCAGCAGGCTA-1-2     inferior turbinate right nostril
# AATCGGTGTCGGCACT-1-4     inferior turbinate right nostril
#
#                         tissue_sampling_method  \
# GCGACCATCCCTAACC_SC22               donor_lung
# P2_1_GCGCAACCAGTTAACC       surgical_resection
# GCTCTGTAGTGCTGCC_SC27               donor_lung
# P2_8_TTAGGACGTTCAGGCC       surgical_resection
# CTTGATTGTCAGTTTG_T164               donor_lung
# ...                                        ...
# ACCTTTACATTAACCG_T120               donor_lung
# CATTATCTCCATGAAC_F01639             donor_lung
# AGGCCGTGTGTGACCC-SC56               donor_lung
# CGATGGCAGCAGGCTA-1-2                  scraping
# AATCGGTGTCGGCACT-1-4                  scraping
#
#                                                     cell_type      assay  \
# GCGACCATCCCTAACC_SC22                     alveolar macrophage  10x 3' v2
# P2_1_GCGCAACCAGTTAACC                     natural killer cell  10x 3' v2
# GCTCTGTAGTGCTGCC_SC27                      type II pneumocyte  10x 3' v2
# P2_8_TTAGGACGTTCAGGCC                     alveolar macrophage  10x 3' v2
# CTTGATTGTCAGTTTG_T164                  respiratory basal cell  10x 3' v3
# ...                                                       ...        ...
# ACCTTTACATTAACCG_T120                  respiratory basal cell  10x 3' v2
# CATTATCTCCATGAAC_F01639  CD1c-positive myeloid dendritic cell  10x 5' v1
# AGGCCGTGTGTGACCC-SC56                      type II pneumocyte  10x 3' v2
# CGATGGCAGCAGGCTA-1-2                                club cell  10x 5' v1
# AATCGGTGTCGGCACT-1-4                                club cell  10x 5' v2
#
#                         disease      organism     sex              tissue  \
# GCGACCATCCCTAACC_SC22    normal  Homo sapiens  female     lung parenchyma
# P2_1_GCGCAACCAGTTAACC    normal  Homo sapiens    male     lung parenchyma
# GCTCTGTAGTGCTGCC_SC27    normal  Homo sapiens  female     lung parenchyma
# P2_8_TTAGGACGTTCAGGCC    normal  Homo sapiens    male  respiratory airway
# CTTGATTGTCAGTTTG_T164    normal  Homo sapiens    male  respiratory airway
# ...                         ...           ...     ...                 ...
# ACCTTTACATTAACCG_T120    normal  Homo sapiens  female  respiratory airway
# CATTATCTCCATGAAC_F01639  normal  Homo sapiens    male     lung parenchyma
# AGGCCGTGTGTGACCC-SC56    normal  Homo sapiens  female     lung parenchyma
# CGATGGCAGCAGGCTA-1-2     normal  Homo sapiens    male                nose
# AATCGGTGTCGGCACT-1-4     normal  Homo sapiens  female                nose
#
#                         self_reported_ethnicity        development_stage
# GCGACCATCCCTAACC_SC22                  European  49-year-old human stage
# P2_1_GCGCAACCAGTTAACC                  European  46-year-old human stage
# GCTCTGTAGTGCTGCC_SC27                  European  47-year-old human stage
# P2_8_TTAGGACGTTCAGGCC                  European  46-year-old human stage
# CTTGATTGTCAGTTTG_T164                  European  66-year-old human stage
# ...                                         ...                      ...
# ACCTTTACATTAACCG_T120                  European  57-year-old human stage
# CATTATCTCCATGAAC_F01639                European  53-year-old human stage
# AGGCCGTGTGTGACCC-SC56                  European  57-year-old human stage
# CGATGGCAGCAGGCTA-1-2                   European  41-year-old human stage
# AATCGGTGTCGGCACT-1-4           admixed ancestry  27-year-old human stage
#
# [584944 rows x 67 columns]

# %%
HLCA_core.obs.columns
# Out:
# Index(['suspension_type', 'donor_id', 'is_primary_data',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'tissue_ontology_term_id',
#        'organism_ontology_term_id', 'sex_ontology_term_id', 'BMI',
#        'age_or_mean_of_age_range', 'age_range', 'anatomical_region_ccf_score',
#        'ann_coarse_for_GWAS_and_modeling', 'ann_finest_level', 'ann_level_1',
#        'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5',
#        'cause_of_death', 'dataset', 'entropy_dataset_leiden_3',
#        'entropy_original_ann_level_1_leiden_3',
#        'entropy_original_ann_level_2_clean_leiden_3',
#        'entropy_original_ann_level_3_clean_leiden_3',
#        'entropy_subject_ID_leiden_3', 'fresh_or_frozen', 'leiden_1',
#        'leiden_2', 'leiden_3', 'leiden_4', 'leiden_5', 'log10_total_counts',
#        'lung_condition', 'mixed_ancestry', 'n_genes_detected',
#        'original_ann_highest_res', 'original_ann_level_1',
#        'original_ann_level_2', 'original_ann_level_3', 'original_ann_level_4',
#        'original_ann_level_5', 'original_ann_nonharmonized',
#        'reannotation_type', 'reference_genome', 'sample', 'scanvi_label',
#        'sequencing_platform', 'size_factors', 'smoking_status', 'study',
#        'subject_type', 'tissue_dissociation_protocol', 'tissue_level_2',
#        'tissue_level_3', 'tissue_sampling_method', 'cell_type', 'assay',
#        'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity',
#        'development_stage'],
#       dtype='object')

# %%
HLCA_core.obs["assay"].value_counts()
# Out:
# 10x 3' v2    328263
# 10x 5' v1    130370
# 10x 3' v3     86309
# 10x 5' v2     37081
# 10x 3' v1      2921
# Name: assay, dtype: int64

# %%
HLCA_core.obs["sequencing_platform"].value_counts()
# Out:
# Illumina NovaSeq 6000                         199172
# Illumina HiSeq 4000                           159395
# Illumina NextSeq 500                           98668
# Illumina NovaSeq 6000 S4                       57225
# Illumina NovaSeq 6000 S1                       41001
# Illumina NovaSeq 6000 S2                       21371
# Illumina NovaSeq 6000; Illumina HiSeq 4000      5815
# Illumina NovaSeq 6000 SP                        1920
# Name: sequencing_platform, dtype: int64

# %%
HLCA_core.obs["donor_id"].value_counts()
# Out:
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747NU_CZI02           36814
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747donor 2            28792
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747NU_CZI01           28029
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747donor 3            24667
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-09             16187
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D353               15380
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747390C               14728
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747356C               13557
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-04             13476
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D372               13264
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-10             12801
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-03             12736
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_4837472020-3173-NC004    11725
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747lafy_donor_6       10172
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD67             10093
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D367                9508
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD103             9395
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD106             9331
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD84              9134
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_4837472020-3173-NC006     8617
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD68              7850
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD95              7560
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D363                7543
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_4837472020-3173-NC008     7538
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747donor 1             7523
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD94              7286
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747368C                7269
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747Donor_07            7268
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D354                6816
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_4837472020-3173-NC005     6255
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD104             6180
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D344                6001
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD071             5972
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D339                5790
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747Donor_01            5390
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747Donor_05            5282
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D326                5181
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747Donor_04            5164
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747Donor_03            5163
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_4837472020-3173-NC002     4884
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747Donor_08            4880
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-07              4660
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0005             4516
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747lafy_donor_4        4431
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD98              4305
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747Donor_06            4241
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0007             4201
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747Donor_02            3832
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747296C                3771
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D322                3628
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T85                 3583
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-06              3561
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD92              3474
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD66              3440
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T153                3434
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_4837472020-3173-NC007     3427
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747lafy_donor_3        3385
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747302C                3342
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T101                3295
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747lafy_donor_5        3272
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0008             3252
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T164                3247
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD101             3115
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_4837472020-3173-NC003     3111
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-08              3025
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T167                2867
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T166                2626
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0001             2542
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747298C                2425
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD70              2322
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T89                 2232
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T90                 2230
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747lafy_donor_2        2217
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-11              2127
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T165                2118
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747290B                1991
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0014             1920
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T120                1786
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T126                1775
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0019             1753
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0009             1739
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T154                1649
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0015             1465
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T121                1419
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0017             1411
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747D337                1376
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD85              1332
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747T137                1332
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0006             1296
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD69              1208
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD107             1028
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0012              957
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-02               942
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747GRO-01               887
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0020              782
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747THD0010              748
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747lafy_donor_1         704
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD072              601
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD078              436
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD080              400
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD077              377
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747292B                 371
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747284C                 331
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD073              278
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD105              140
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD076               47
# homosapiens_None_2023_None_sikkemalisa_001_d10_1101_2022_03_10_483747VUHD87                 8
# Name: donor_id, dtype: int64

# %%
HLCA_core.obs["tissue"].value_counts()
# Out:
# lung parenchyma       333468
# respiratory airway    173197
# nose                   78279
# Name: tissue, dtype: int64

# %%
HLCA_core.obs[["tissue","anatomical_region_ccf_score"]].value_counts()
# Out:
# tissue              anatomical_region_ccf_score
# lung parenchyma     0.97                           333468
# nose                0.00                            78279
# respiratory airway  0.72                            74464
#                     0.36                            54004
#                     0.81                            27543
#                     0.50                             9417
#                     0.64                             7769
# dtype: int64

# %% [markdown]
# ## We select only lung parenchyma cells to match our studied Visium ST samples

# %%
HLCA_core_parenchyma = HLCA_core[HLCA_core.obs["tissue"] == "lung parenchyma"].copy()

# %%
#Explora HLCA parenchyma object
HLCA_core_parenchyma
# Out:
# AnnData object with n_obs × n_vars = 333468 × 28024
#     obs: 'suspension_type', 'donor_id', 'is_primary_data', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'tissue_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'BMI', 'age_or_mean_of_age_range', 'age_range', 'anatomical_region_ccf_score', 'ann_coarse_for_GWAS_and_modeling', 'ann_finest_level', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'cause_of_death', 'dataset', 'entropy_dataset_leiden_3', 'entropy_original_ann_level_1_leiden_3', 'entropy_original_ann_level_2_clean_leiden_3', 'entropy_original_ann_level_3_clean_leiden_3', 'entropy_subject_ID_leiden_3', 'fresh_or_frozen', 'leiden_1', 'leiden_2', 'leiden_3', 'leiden_4', 'leiden_5', 'log10_total_counts', 'lung_condition', 'mixed_ancestry', 'n_genes_detected', 'original_ann_highest_res', 'original_ann_level_1', 'original_ann_level_2', 'original_ann_level_3', 'original_ann_level_4', 'original_ann_level_5', 'original_ann_nonharmonized', 'reannotation_type', 'reference_genome', 'sample', 'scanvi_label', 'sequencing_platform', 'size_factors', 'smoking_status', 'study', 'subject_type', 'tissue_dissociation_protocol', 'tissue_level_2', 'tissue_level_3', 'tissue_sampling_method', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'batch_condition', 'default_embedding', 'schema_version', 'title'
#     obsm: 'X_scanvi_emb', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
#Explore finest annotation level
HLCA_core_parenchyma.obs["ann_finest_level"].value_counts()
# Out:
# Alveolar macrophages             65291
# AT2                              59457
# Monocyte-derived Mph             26057
# CD4 T cells                      15702
# Classical monocytes              15454
# CD8 T cells                      14932
# NK cells                         14878
# EC general capillary             14329
# Multiciliated (non-nasal)        10180
# Adventitial fibroblasts           9739
# Non-classical monocytes           8415
# AT1                               7411
# EC arterial                       6866
# EC venous pulmonary               6194
# Alveolar Mph CCL3+                5917
# EC aerocyte capillary             5881
# DC2                               5623
# Mast cells                        4754
# Interstitial Mph perivascular     4604
# Alveolar fibroblasts              4349
# pre-TB secretory                  3964
# Lymphatic EC mature               3777
# B cells                           2415
# Pericytes                         2248
# Smooth muscle                     1939
# EC venous systemic                1716
# Plasma cells                      1255
# Alveolar Mph MT-positive          1197
# AT0                               1169
# Alveolar Mph proliferating        1009
# Club (non-nasal)                   969
# AT2 proliferating                  967
# Myofibroblasts                     600
# Lymphatic EC differentiating       556
# SM activated stress response       487
# Suprabasal                         402
# T cells proliferating              400
# Peribronchial fibroblasts          288
# Subpleural fibroblasts             276
# Migratory DCs                      268
# DC1                                249
# Mesothelium                        229
# Basal resting                      222
# Deuterosomal                       205
# Plasmacytoid DCs                   171
# Goblet (nasal)                     114
# Goblet (bronchial)                  75
# Smooth muscle FAM83D+               57
# Hematopoietic stem cells            57
# Ionocyte                            34
# Lymphatic EC proliferating          28
# Club (nasal)                        20
# Neuroendocrine                      19
# Multiciliated (nasal)               18
# Hillock-like                        17
# Goblet (subsegmental)               12
# Tuft                                 3
# SMG duct                             2
# SMG mucous                           1
# Name: ann_finest_level, dtype: int64

# %% [markdown]
# ## We select only cell types with at least 150 cells (finest annotation level) present in the HLCA core lung parenchyma object for a more robust reference model training

# %%
min_cells = 150

# %%
counts = HLCA_core_parenchyma.obs.groupby('ann_finest_level')['ann_finest_level'].count()

# %%
minimumValueCells = counts[counts>=min_cells]

# %%
HLCA_core_parenchyma_filter = HLCA_core_parenchyma[HLCA_core_parenchyma.obs['ann_finest_level'].isin(minimumValueCells.index)]

# %%
HLCA_core_parenchyma_filter
# Out:
# View of AnnData object with n_obs × n_vars = 333011 × 28024
#     obs: 'suspension_type', 'donor_id', 'is_primary_data', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'tissue_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'BMI', 'age_or_mean_of_age_range', 'age_range', 'anatomical_region_ccf_score', 'ann_coarse_for_GWAS_and_modeling', 'ann_finest_level', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'cause_of_death', 'dataset', 'entropy_dataset_leiden_3', 'entropy_original_ann_level_1_leiden_3', 'entropy_original_ann_level_2_clean_leiden_3', 'entropy_original_ann_level_3_clean_leiden_3', 'entropy_subject_ID_leiden_3', 'fresh_or_frozen', 'leiden_1', 'leiden_2', 'leiden_3', 'leiden_4', 'leiden_5', 'log10_total_counts', 'lung_condition', 'mixed_ancestry', 'n_genes_detected', 'original_ann_highest_res', 'original_ann_level_1', 'original_ann_level_2', 'original_ann_level_3', 'original_ann_level_4', 'original_ann_level_5', 'original_ann_nonharmonized', 'reannotation_type', 'reference_genome', 'sample', 'scanvi_label', 'sequencing_platform', 'size_factors', 'smoking_status', 'study', 'subject_type', 'tissue_dissociation_protocol', 'tissue_level_2', 'tissue_level_3', 'tissue_sampling_method', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'batch_condition', 'default_embedding', 'schema_version', 'title'
#     obsm: 'X_scanvi_emb', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
HLCA_core_parenchyma_filter.obs["ann_finest_level"].value_counts()
# Out:
# Alveolar macrophages             65291
# AT2                              59457
# Monocyte-derived Mph             26057
# CD4 T cells                      15702
# Classical monocytes              15454
# CD8 T cells                      14932
# NK cells                         14878
# EC general capillary             14329
# Multiciliated (non-nasal)        10180
# Adventitial fibroblasts           9739
# Non-classical monocytes           8415
# AT1                               7411
# EC arterial                       6866
# EC venous pulmonary               6194
# Alveolar Mph CCL3+                5917
# EC aerocyte capillary             5881
# DC2                               5623
# Mast cells                        4754
# Interstitial Mph perivascular     4604
# Alveolar fibroblasts              4349
# pre-TB secretory                  3964
# Lymphatic EC mature               3777
# B cells                           2415
# Pericytes                         2248
# Smooth muscle                     1939
# EC venous systemic                1716
# Plasma cells                      1255
# Alveolar Mph MT-positive          1197
# AT0                               1169
# Alveolar Mph proliferating        1009
# Club (non-nasal)                   969
# AT2 proliferating                  967
# Myofibroblasts                     600
# Lymphatic EC differentiating       556
# SM activated stress response       487
# Suprabasal                         402
# T cells proliferating              400
# Peribronchial fibroblasts          288
# Subpleural fibroblasts             276
# Migratory DCs                      268
# DC1                                249
# Mesothelium                        229
# Basal resting                      222
# Deuterosomal                       205
# Plasmacytoid DCs                   171
# Name: ann_finest_level, dtype: int64

# %% [markdown]
# ## Save HLCA filtered object for reference model training

# %%
#Write filtered lung parenchyma annData object
HLCA_core_parenchyma_filter.write_h5ad('HLCA_publication/HLCA_core_parenchyma_filter.h5ad', compression='gzip')
